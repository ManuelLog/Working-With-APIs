# %% [markdown]
# # Use this notbook for your 3 choices of APIs

# %% [markdown]
# # 1 table

# %%
import requests

Procurement = requests.get("https://data.aishub.net/stations.php?username=A&output=B&compress=C&id=D")
print("Procurement:", Procurement.status_code)
# Out:
# Procurement: 200

# %%
FBI = requests.get("https://api.fbi.gov/wanted/v1/list")
print("FBI:", FBI.status_code)
# Out:
# FBI: 200

# %%
import json
response = requests.get('https://api.fbi.gov/wanted/v1/list')

# %%
results = response.json()
results
# Out:
# {'total': 964,
#  'items': [{'reward_text': 'The FBI is offering a reward of up to $10,000 for information leading to the arrest of Christopher Gardner.',
#    'aliases': ['Chris Gardner', 'Christopher Charles Gardner'],
#    'publication': '2021-12-08T10:43:00',
#    'url': 'https://www.fbi.gov/wanted/wcc/christopher-c-gardner',
#    'warning_message': 'SHOULD BE CONSIDERED AN INTERNATIONAL FLIGHT RISK.',
#    'age_max': None,
#    'additional_information': None,
#    'weight_min': 175,
#    'height_min': 71,
#    'field_offices': ['milwaukee'],
#    'age_min': None,
#    'occupations': ['Classic/Antique/Rare Car Collector'],
#    'height_max': 71,
#    'details': None,
#    'weight_max': 175,
#    'coordinates': [],
#    'sex': 'Male',
#    'scars_and_marks': 'Gardner may have scars on the left side of his chin and on his left forearm.',
#    'build': None,
#    'reward_max': 0,
#    'nationality': 'American',
#    'reward_min': 0,
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

data = pd.DataFrame(results)
data.head(10)
# Out:
#    total                                              items  page
# 0    964  {'reward_text': 'The FBI is offering a reward ...     1
# 1    964  {'reward_text': 'The FBI is offering a reward ...     1
# 2    964  {'reward_text': None, 'aliases': ['Cristian Mo...     1
# 3    964  {'reward_text': None, 'aliases': ['James Von K...     1
# 4    964  {'reward_text': None, 'aliases': None, 'public...     1
# 5    964  {'reward_text': None, 'aliases': None, 'public...     1
# 6    964  {'reward_text': None, 'aliases': None, 'public...     1
# 7    964  {'reward_text': 'The FBI is offering a reward ...     1
# 8    964  {'reward_text': 'The FBI is offering a reward ...     1
# 9    964  {'reward_text': 'The FBI is offering a reward ...     1

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
dict(data['items'])
pd.DataFrame(dict(data['items']))
pd.DataFrame(dict(data['items'])).transpose()
# Out:
#                                           reward_text  \
# 0   The FBI is offering a reward of up to $10,000 ...
# 1   The FBI is offering a reward of up to $5,000 f...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   The FBI is offering a reward of up to $10,000 ...
# 8   The FBI is offering a reward of up to $5,000 f...
# 9   The FBI is offering a reward of up to $25,000 ...
# 10                                               None
# 11  The FBI is offering a reward of up to $8,000 f...
# 12                                               None
# 13  The United States Government is offering a rew...
# 14                                               None
# 15  The FBI is offering a reward of up to $5,000 f...
# ...

# %%
nested_columns = ['items']
# we will see the dictionary for each column
flat = flatten(data, nested_columns)
flat.head(20)
# Out:
#     total  page                                  items_reward_text  \
# 0     964     1  The FBI is offering a reward of up to $10,000 ...
# 1     964     1  The FBI is offering a reward of up to $5,000 f...
# 2     964     1                                               None
# 3     964     1                                               None
# 4     964     1                                               None
# 5     964     1                                               None
# 6     964     1                                               None
# 7     964     1  The FBI is offering a reward of up to $10,000 ...
# 8     964     1  The FBI is offering a reward of up to $5,000 f...
# 9     964     1  The FBI is offering a reward of up to $25,000 ...
# 10    964     1                                               None
# 11    964     1  The FBI is offering a reward of up to $8,000 f...
# 12    964     1                                               None
# ...

# %% [markdown]
# # 2 table

# %%
AustriaHoliday = requests.get("https://date.nager.at/api/v3/PublicHolidays/2017/AT")
print("AustriaHoliday:", AustriaHoliday.status_code)
# Out:
# AustriaHoliday: 200

# %%
import json
response = requests.get("https://date.nager.at/api/v3/PublicHolidays/2017/AT")

# %%
results = response.json()
results
# Out:
# [{'date': '2017-01-01',
#   'localName': 'Neujahr',
#   'name': "New Year's Day",
#   'countryCode': 'AT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': 1967,
#   'types': ['Public']},
#  {'date': '2017-01-06',
#   'localName': 'Heilige Drei Könige',
#   'name': 'Epiphany',
#   'countryCode': 'AT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2017-04-17',
#   'localName': 'Ostermontag',
#   'name': 'Easter Monday',
#   'countryCode': 'AT',
#   'fixed': False,
#   'global': True,
#   'counties': None,
#   'launchYear': 1642,
#   'types': ['Public']},
#  {'date': '2017-05-01',
#   'localName': 'Staatsfeiertag',
#   'name': 'National Holiday',
#   'countryCode': 'AT',
#   'fixed': True,
#   'global': True,
#   'counties': None,
#   'launchYear': 1955,
#   'types': ['Public']},
#  {'date': '2017-05-25',
#   'localName': 'Christi Himmelfahrt',
#   'name': 'Ascension Day',
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

data = pd.DataFrame(results)
data.head(10)
# Out:
#          date            localName              name countryCode  fixed  \
# 0  2017-01-01              Neujahr    New Year's Day          AT   True
# 1  2017-01-06  Heilige Drei Könige          Epiphany          AT   True
# 2  2017-04-17          Ostermontag     Easter Monday          AT  False
# 3  2017-05-01       Staatsfeiertag  National Holiday          AT   True
# 4  2017-05-25  Christi Himmelfahrt     Ascension Day          AT  False
# 5  2017-06-05        Pfingstmontag       Whit Monday          AT  False
# 6  2017-06-15         Fronleichnam    Corpus Christi          AT  False
# 7  2017-08-15    Maria Himmelfahrt    Assumption Day          AT   True
# 8  2017-10-26     Nationalfeiertag  National Holiday          AT   True
# 9  2017-11-01        Allerheiligen   All Saints' Day          AT   True
#
#    global counties  launchYear     types
# 0    True     None      1967.0  [Public]
# 1    True     None         NaN  [Public]
# 2    True     None      1642.0  [Public]
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
dict(data['types'])
pd.DataFrame(dict(data['types']))
pd.DataFrame(dict(data['types'])).transpose()
# Out:
#          0
# 0   Public
# 1   Public
# 2   Public
# 3   Public
# 4   Public
# 5   Public
# 6   Public
# 7   Public
# 8   Public
# 9   Public
# 10  Public
# 11  Public
# 12  Public

# %%
nested_columns = ['types']
# we will see the dictionary for each column
flat = flatten(data, nested_columns)
flat.head(60)
# Out:
#           date            localName                   name countryCode  fixed  \
# 0   2017-01-01              Neujahr         New Year's Day          AT   True
# 1   2017-01-06  Heilige Drei Könige               Epiphany          AT   True
# 2   2017-04-17          Ostermontag          Easter Monday          AT  False
# 3   2017-05-01       Staatsfeiertag       National Holiday          AT   True
# 4   2017-05-25  Christi Himmelfahrt          Ascension Day          AT  False
# 5   2017-06-05        Pfingstmontag            Whit Monday          AT  False
# 6   2017-06-15         Fronleichnam         Corpus Christi          AT  False
# 7   2017-08-15    Maria Himmelfahrt         Assumption Day          AT   True
# 8   2017-10-26     Nationalfeiertag       National Holiday          AT   True
# 9   2017-11-01        Allerheiligen        All Saints' Day          AT   True
# 10  2017-12-08     Mariä Empfängnis  Immaculate Conception          AT   True
# ...

# %% [markdown]
# # 3 table

# %%
JKRowling = requests.get("https://openlibrary.org/search/authors.json?q=j%20k%20rowling")
print("JKRowling:", JKRowling.status_code)
# Out:
# JKRowling: 200

# %%
import json
response = requests.get(' https://openlibrary.org/search/authors.json?q=j%20k%20rowling')

# %%
results = response.json()
results
# Out:
# {'numFound': 3,
#  'start': 0,
#  'numFoundExact': True,
#  'docs': [{'key': 'OL23919A',
#    'type': 'author',
#    'name': 'J. K. Rowling',
#    'alternate_names': ['Joanne Rowling',
#     'Joanne K. Rowling',
#     'Jo Murray',
#     'Kennilworthy Whisp',
#     'JK Rowling',
#     'Robert Galbraith',
#     'Джоан Роулінг',
#     'Dzhoan Rouling',
#     'J.K. Rowling',
#     'ROWLING',
#     'روبرت غالبريث - Robert Galbraith',
#     'Rouling Dzh.K.',
#     'Newt Scamander',
#     'Newton Scamander'],
#    'birth_date': '31 July 1965',
#    'top_work': "Harry Potter and the Philosopher's Stone",
#    'work_count': 319,
#    'top_subjects': ['Fiction',
#     "Children's fiction",
#     'Fantasy fiction',
#     'New York Times bestseller',
#     'Harry Potter',
#     'Wizards, fiction',
#     'Magic',
#     'England, fiction',
#     'Wizards',
#     'Juvenile fiction'],
#    '_version_': 1745886434789687315},
#   {'key': 'OL10650745A',
#    'type': 'author',
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

data = pd.DataFrame(results)
data.head(10)
# Out:
#    numFound  start  numFoundExact  \
# 0         3      0           True
# 1         3      0           True
# 2         3      0           True
#
#                                                 docs
# 0  {'key': 'OL23919A', 'type': 'author', 'name': ...
# 1  {'key': 'OL10650745A', 'type': 'author', 'name...
# 2  {'key': 'OL10716251A', 'type': 'author', 'name...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
dict(data['docs'])
pd.DataFrame(dict(data['docs']))
pd.DataFrame(dict(data['docs'])).transpose()
# Out:
#            key    type                                 name  \
# 0     OL23919A  author                        J. K. Rowling
# 1  OL10650745A  author  Lia Wyler (Tradutor) J. K. Rowling
# 2  OL10716251A  author                        J. K. Rowling
#
#                                      alternate_names    birth_date  \
# 0  [Joanne Rowling, Joanne K. Rowling, Jo Murray,...  31 July 1965
# 1                                                NaN           NaN
# 2                                                NaN           NaN
#
#                                    top_work work_count  \
# 0  Harry Potter and the Philosopher's Stone        319
# 1                                       NaN          0
# 2                                       NaN          0
#
#                                         top_subjects            _version_
# 0  [Fiction, Children's fiction, Fantasy fiction,...  1745886434789687315
# 1                                                NaN  1743399222225403904
# ...

# %%
nested_columns = ['docs']

# we will see the dictionary for each column
flat = flatten(data, nested_columns)
flat.head() #to see all the columns
# Out:
#    numFound  start  numFoundExact     docs_key docs_type  \
# 0         3      0           True     OL23919A    author
# 1         3      0           True  OL10650745A    author
# 2         3      0           True  OL10716251A    author
#
#                              docs_name  \
# 0                        J. K. Rowling
# 1  Lia Wyler (Tradutor) J. K. Rowling
# 2                        J. K. Rowling
#
#                                 docs_alternate_names docs_birth_date  \
# 0  [Joanne Rowling, Joanne K. Rowling, Jo Murray,...    31 July 1965
# 1                                                NaN             NaN
# 2                                                NaN             NaN
#
#                               docs_top_work docs_work_count  \
# 0  Harry Potter and the Philosopher's Stone             319
# 1                                       NaN               0
# 2                                       NaN               0
#
# ...

# %%
import requests

# %%
import json

# %%
casa = requests.get("https://datos.madrid.es/egob/catalogo/205026-0-cementerios.json")
print("casa:", casa.status_code)
# Out:
# casa: 200

# %%
response = requests.get("https://datos.madrid.es/egob/catalogo/205026-0-cementerios.json")

# %%
results = response.json()
results
# Out:
# {'@context': {'c': 'http://www.w3.org/2002/12/cal#',
#   'dcterms': 'http://purl.org/dc/terms/',
#   'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#   'loc': 'http://purl.org/ctic/infraestructuras/localizacion#',
#   'org': 'http://purl.org/ctic/infraestructuras/organizacion#',
#   'vcard': 'http://www.w3.org/2006/vcard/ns#',
#   'schema': 'https://schema.org/',
#   'title': 'vcard:fn',
#   'id': 'dcterms:identifier',
#   'relation': 'dcterms:relation',
#   'references': 'dcterms:references',
#   'address': 'vcard:adr',
#   'area': 'loc:barrio',
#   'district': 'loc:distrito',
#   'locality': 'vcard:locality',
#   'postal-code': 'vcard:postal-code',
#   'street-address': 'vcard:street-address',
#   'location': 'vcard:geo',
#   'latitude': 'geo:lat',
#   'longitude': 'geo:long',
#   'organization': 'vcard:org',
#   'organization-desc': 'dcterms:description',
#   'accesibility': 'org:accesibilidad',
#   'services': 'org:servicios',
#   'schedule': 'org:horario',
# ...

# %%
state = pd.DataFrame(results["@context"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 state = pd.DataFrame(results["@context"])
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

data = pd.DataFrame(results)
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 4>()
#       1 import pandas as pd
#       2 pd.set_option("display.max_rows", 0)
# ----> 4 data = pd.DataFrame(results)
#       5 data.head(10)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# ...
